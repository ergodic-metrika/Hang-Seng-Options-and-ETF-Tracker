# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
####################HSI VS HSI VIX############
excel_2= pd.ExcelFile('D:\Derivatives Trading\HSI_VIX.xlsx')
sheet_name_2 = 'HSI_VIX' 
df_2 = excel_2.parse(sheet_name_2)
Time=df_2["Date"]
HSI_VIX=df_2["VHSI"]
HSI=df_2["HSI"]

# %%
# Create a new figure and an axis object
fig, ax1 = plt.subplots()

# Plot the first data set with the first y-axis
color = 'tab:cyan'
ax1.set_xlabel('Date')
ax1.set_ylabel('HSI_VIX', color=color)
ax1.plot(Time, VHSI, color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis that shares the same x-axis
ax2 = ax1.twinx()

# Plot the second data set with the second y-axis
color = 'tab:blue'
ax2.set_ylabel('HSI', color=color)
ax2.plot(Time, HSI, color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Title of the plot
plt.title('HSI_VIX and HSI over Time')

# Show the plot with a legend and a tight layout
fig.tight_layout()
plt.show()
